# %%
# !pip install openai

# %%
import openai
import json
from io import BytesIO
import fitz  # PyMuPDF
import pdfplumber
import PyPDF2
from pdfminer.high_level import extract_text
import pytesseract
from pdf2image import convert_from_bytes

modelo = 'gpt-3.5-turbo'

# Configura tu clave de API

# %%
def convert_uploaded_file_to_bytesio(uploaded_file):
    """Convierte un archivo subido en Django a un objeto BytesIO"""
    file_bytes = uploaded_file.read()  # Leer el contenido del archivo
    return BytesIO(file_bytes)  # Convertirlo en BytesIO


def extract_text_pymupdf(pdf_bytes):
    """Extraer texto por página usando PyMuPDF"""
    doc = fitz.open(stream=pdf_bytes.read(), filetype="pdf")
    return [page.get_text("text") for page in doc]


def extract_text_pdfplumber(pdf_bytes):
    """Extraer texto por página usando pdfplumber"""
    pdf_bytes.seek(0)
    with pdfplumber.open(pdf_bytes) as pdf:
        return [page.extract_text() or "" for page in pdf.pages]


def extract_text_pypdf2(pdf_bytes):
    """Extraer texto por página usando PyPDF2"""
    pdf_bytes.seek(0)
    reader = PyPDF2.PdfReader(pdf_bytes)
    return [page.extract_text() or "" for page in reader.pages]


def extract_text_pdfminer(pdf_path):
    """Extrae texto y corrige el número de páginas"""
    text = extract_text(pdf_path)
    # Separar páginas por el caracter de salto de página
    pages = text.split("\f")

    # Filtrar páginas vacías para evitar falsos positivos
    pages = [p for p in pages if p.strip()]

    return pages  # Devuelve el array de páginas


def extract_text_tesseract(pdf_bytes):
    """Extraer texto de imágenes escaneadas usando Tesseract OCR"""
    pdf_bytes.seek(0)
    images = convert_from_bytes(pdf_bytes.read())  # Convertir PDF en imágenes
    return [pytesseract.image_to_string(img) for img in images]


def extract_text_combined(pdf_file):
    """Convierte el archivo a BytesIO y almacena los textos en 5 arrays diferentes"""
    pdf_bytes = convert_uploaded_file_to_bytesio(pdf_file)

    print('generando pymupdf...')
    text_pymupdf = extract_text_pymupdf(BytesIO(pdf_bytes.getvalue()))
    print('generando pdfplumber...')
    text_pdfplumber = extract_text_pdfplumber(BytesIO(pdf_bytes.getvalue()))
    print('generando pypdf2...')
    text_pypdf2 = extract_text_pypdf2(BytesIO(pdf_bytes.getvalue()))
    print('generando pdfminer...')
    text_pdfminer = extract_text_pdfminer(BytesIO(pdf_bytes.getvalue()))
    # print('generando tesseract...')
    # text_tesseract = extract_text_tesseract(BytesIO(pdf_bytes.getvalue()))

    return text_pymupdf, text_pdfplumber, text_pypdf2, text_pdfminer  # , text_tesseract


def extraer_texto_pdf(file):
    text_pymupdf, text_pdfplumber, text_pypdf2, text_pdfminer = extract_text_combined(
        file)

    file.close()

    respuesta = ''

    for i in range(len(text_pdfminer)):
        text = '-¿!11441165473941=(-' + text_pymupdf[i] + '-¿!11441165473941=(-' + text_pdfplumber[i] + '-¿!11441165473941=(-' + \
            text_pypdf2[i] + '-¿!11441165473941=(-' + \
            text_pdfminer[i]  # + '-¿!11441165473941=(-' + text_tesseract[i]
        try:
            response = client.chat.completions.create(
                model=modelo,
                messages=[
                    {"role": "system",
                        "content": "He usado 5 librerías para extraer el texto de un pdf. Los 4 resultados son los siguientes. Necesito que me des un texto limpio final usando la información de las 4 extracciones. No escribas nada más que el texto limpio final. La separación entre texto y texto es: '-¿!11441165473941=(-'"},
                    {"role": "user", "content": text},
                ],
                temperature=0.7
            )
            respuesta += response.choices[0].message.content
        except Exception as e:
            return f"Error en la solicitud a OpenAI: {str(e)}"

    return respuesta

# %%
# Función para analizar el temario y extraer apartados y subapartados
def analizar_temario(temario_texto):
    prompt = """
    Eres experto en analizar temarios académicos.
    Analiza el texto proporcionado y devuelve los apartados y subapartados en formato array.

    Ejemplo del formato esperado:
    [
        "BLOQUE I. FISIOLOGÍA DE LA AUDICIÓN HUMANA",
        "TEMA 1. ESTUDIO FÍSICO DEL SONIDO",
        "1. FUENTE SONORA VIBRANTE",
        "1.1. Cualidades esenciales de las ondas sonoras",
        "2. MEDIO DE PROPAGACIÓN",
        "a) REFLEXIÓN, ECO Y REVERBERACIÓN",
        "b) REFRACCIÓN",
        "Absorción",
        "Resonancia",
        "Efecto Doppler"
    ]
    """
    respuesta = client.chat.completions.create(
        model=modelo,
        messages=[{"role": "system", "content": prompt}, {"role": "user", "content": temario_texto}]
    )

    try:
        apartados = json.loads(respuesta.choices[0].message.content)
    except json.JSONDecodeError as e:
        print(f"Error al decodificar el JSON: {e}")
    return apartados

# Función para generar preguntas tipo test en el formato JSON solicitado

def generar_preguntas_json(texto, apartados, cantidad=20):
    # prompt = f"""
    # Eres experto en crear preguntas tipo test sobre temarios académicos.
    # Te voy a entregar un texto y luego te pediré preguntas tipo test sobre él.
    # Las preguntas tipo test deben crearse con el siguiente formato JSON:
    # {{
    # "preguntas": [
    #     {{
    #     "texto": "Enunciado de la pregunta 1",
    #     "respuestas": [
    #         {{
    #         "texto": "Respuesta CORRECTA"
    #         }},
    #         {{
    #         "texto": "Respuesta 2"
    #         }},
    #         {{
    #         "texto": "Respuesta 3"
    #         }},
    #         {{
    #         "texto": "Respuesta 4"
    #         }}
    #     ],
    #     "ayuda": "Explicación de la pregunta usando las palabras literales que aparecen en el texto del temario."
    #     }},
    #     {{
    #     "texto": "Enunciado de la pregunta 2",
    #     "respuestas": [
    #         {{
    #         "texto": "Respuesta CORRECTA"
    #         }},
    #         {{
    #         "texto": "Respuesta 2"
    #         }},
    #         {{
    #         "texto": "Respuesta 3"
    #         }},
    #         {{
    #         "texto": "Respuesta 4"
    #         }}
    #     ],
    #     "ayuda": "Explicación de la pregunta usando las palabras literales que aparecen en el texto del temario."
    #     }}
    # ]
    # }}
    # Es muy importante que la respuesta correcta sea siempre la primera, en todas las preguntas debe ser así.
    
    # El texto con el temario es el siguiente:\n{texto}
    # """
    # messages = [{"role": "system", "content": prompt}]
    # for apartado in apartados:
    #     messages.append({"role": "user", "content": f"""Crea {cantidad} preguntas tipo test sobre el apartado {apartado} del texto"""})

    # respuesta = client.chat.completions.create(
    #     model=modelo,
    #     messages=messages,
    #     response_format={"type": "json_object"}
    # )

    # preguntas_json = respuesta.choices[0].message.content
    # print('--------------')
    # print('PREGUNTAS')
    # print(preguntas_json)
    # print('--------------')
    # return json.loads(preguntas_json)
    
    preguntas_completas = []
    for apartado in apartados:
        print(apartado)
        prompt = f"""
        Eres experto en crear preguntas tipo test sobre temarios académicos.
        Genera 20 preguntas tipo test sobre el apartado "{apartado}" del texto proporcionado.
        La finalidad de las preguntas es conseguir estudiar y aprender de manera exitosa el temario.
        
        Las preguntas deben estar en el siguiente formato JSON:
        {{
            "preguntas": [
                {{
                    "texto": "Enunciado de la pregunta",
                    "respuestas": [
                        {{"texto": "Respuesta CORRECTA"}},
                        {{"texto": "Respuesta 2"}},
                        {{"texto": "Respuesta 3"}},
                        {{"texto": "Respuesta 4"}}
                    ],
                    "ayuda": "Explicación de la pregunta usando las palabras literales que aparecen en el texto del temario."
                }}
            ]
        }}

        El texto del temario es el siguiente:
        {texto}
        """
        
        respuesta = client.chat.completions.create(
            model=modelo,
            messages=[{"role": "system", "content": prompt}],
            response_format={"type": "json_object"}
        )

        # Agregar las preguntas generadas a la lista completa
        try:
            preguntas_json = json.loads(respuesta.choices[0].message.content)
            print(preguntas_json, "\n\n")
            preguntas_completas.extend(preguntas_json["preguntas"])
        except json.JSONDecodeError as e:
            print(f"Error en el JSON del apartado {apartado}: {e}")

    print(f"Se generaron {len(preguntas_completas)} preguntas en total.")
    return preguntas_completas

# Función para analizar la cobertura del temario

def analizar_cobertura(temario, preguntas_generadas):
    prompt = f"Analiza si las siguientes preguntas cubren todo el temario:\nTemario: {temario}\nPreguntas: {preguntas_generadas}\nIndica los apartados no cubiertos."

    respuesta = client.chat.completions.create(
        model=modelo,
        messages=[{"role": "user", "content": prompt}],
        # max_tokens=500
        response_format={"type": "json_object"}
    )

    temas_no_cubiertos = respuesta.choices[0].message.content
    print('--------------')
    print('no cobertura')
    print(temas_no_cubiertos)
    print('--------------')
    return temas_no_cubiertos.split("\n")

# Función para estructurar todas las preguntas en un JSON unificado

def estructurar_en_json(apartados, preguntas_por_apartado):
    resultado = {
        "preguntas": []
    }

    for apartado, preguntas in zip(apartados, preguntas_por_apartado):
        resultado["preguntas"].extend(preguntas["preguntas"])

    return json.dumps(resultado, indent=4, ensure_ascii=False)

# Función principal para generar la batería completa de preguntas

def generar_bateria_completa(temario_texto):
    # Paso 1: Análisis del temario
    apartados = analizar_temario(temario_texto)
    # print('\n\n', apartados)
    # Paso 2: Generar 20 preguntas por cada apartado en el formato JSON solicitado
    # preguntas = []
    # for apartado in apartados:
    #     preguntas.append(generar_preguntas_json(temario_texto, apartados, 20))
    # print('\n\n', preguntas)
    
    preguntas_generadas = generar_preguntas_json(temario_texto, apartados, 20)

    # # Paso 3: Analizar la cobertura del temario
    # preguntas_generadas = json.dumps(preguntas_por_apartado)
    # temas_no_cubiertos = analizar_cobertura(temario_texto, preguntas_generadas)

    # # Paso 4: Generar 10 preguntas adicionales para temas no cubiertos
    # preguntas_adicionales = [
    #     generar_preguntas_json(tema, numero_apartado, 10)
    #     for numero_apartado, tema in enumerate(temas_no_cubiertos, start=1)
    # ]

    # # Unir las preguntas originales con las adicionales
    # preguntas_por_apartado.extend(preguntas_adicionales)

    # # Paso 5: Devolver el JSON con el formato especificado
    # resultado_json = estructurar_en_json(apartados, preguntas_por_apartado)
    
    return preguntas_generadas


resultado = generar_bateria_completa(temario)
print(resultado)
# Out:
# BLOQUE I. FISIOLOGÍA DE LA AUDICIÓN HUMANA
# {'preguntas': [{'texto': '¿Qué son las ondas sonoras?', 'respuestas': [{'texto': 'Ondas mecánicas de presión que se propagan en un medio elástico y denso'}, {'texto': 'Ondas electromagnéticas que se propagan en el aire'}, {'texto': 'Ondas de luz que se mueven en el agua'}, {'texto': 'Ondas eléctricas que se transmiten por el metal'}], 'ayuda': 'Las ondas sonoras son aquellas que, tras pasar por nuestro sistema auditivo, se convierten en información que el cerebro descodifica. Son ondas mecánicas de presión que se propagan en un medio elástico y denso.'}, {'texto': '¿Cuál es la unidad de medida de la frecuencia?', 'respuestas': [{'texto': 'Hercios (Hz)'}, {'texto': 'Decibelios (dB)'}, {'texto': 'Pascales (Pa)'}, {'texto': 'Vatios (W)'}], 'ayuda': 'La frecuencia se mide en hercios (Hz).'}, {'texto': '¿Qué cualidad del sonido está relacionada con la amplitud?', 'respuestas': [{'texto': 'Intensidad'}, {'texto': 'Timbre'}, {'texto': 'Frecuencia'}, {'texto': 'Duración'}], 'ayuda': 'La amplitud del sonido está relacionada con la intensidad, que es el grado de movimiento de las moléculas de aire que componen una onda.'}, {'texto': "¿A qué se refiere el concepto de 'nivel de presión sonora (SPL)'?", 'respuestas': [{'texto': 'Intensidad percibida del sonido'}, {'texto': 'Intensidad emitida del sonido'}, {'texto': 'Intensidad por decibelios'}, {'texto': 'Intensidad por pascales'}], 'ayuda': 'El nivel de presión sonora (SPL) se refiere a la intensidad percibida del sonido.'}, {'texto': '¿Qué son los tonos simples en relación a las ondas sonoras?', 'respuestas': [{'texto': 'Una única onda sinusoidal con una sola frecuencia'}, {'texto': 'La superposición de múltiples ondas sinusoidales'}, {'texto': 'Ondas de luz monocromáticas'}, {'texto': 'Ruidos ondulatorios irregulares'}], 'ayuda': 'Los tonos simples son una única onda sinusoidal, es decir, una sola frecuencia.'}, {'texto': '¿Qué es el timbre en relación al sonido?', 'respuestas': [{'texto': 'Conjunto de frecuencias/sobretonos que caracterizan un sonido complejo'}, {'texto': 'La duración total de un sonido'}, {'texto': 'La amplitud máxima alcanzada por una onda sonora'}, {'texto': 'La frecuencia más grave de un sonido'}], 'ayuda': 'El timbre es el conjunto de frecuencias o sobretonos que caracterizan a un sonido complejo.'}, {'texto': '¿Qué afecta a la velocidad de propagación del sonido en un medio?', 'respuestas': [{'texto': 'Densidad del medio'}, {'texto': 'Color del medio'}, {'texto': 'Peso del medio'}, {'texto': 'Forma del medio'}], 'ayuda': 'La velocidad de propagación del sonido en un medio es afectada por la densidad del medio. Cuanto más denso el medio, más rápido se propaga el sonido.'}, {'texto': '¿Qué fenómeno es la reflexión del sonido?', 'respuestas': [{'texto': 'Cuando una onda choca contra un obstáculo que no puede traspasar ni rodear'}, {'texto': 'Cuando una onda se dobla al pasar de un medio a otro'}, {'texto': 'Cuando una onda se desvanece con el tiempo'}, {'texto': 'Cuando una onda cambia su dirección al atravesar un material'}], 'ayuda': 'La reflexión del sonido es el fenómeno que ocurre cuando una onda choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': '¿Qué es la reverberación en relación al sonido?', 'respuestas': [{'texto': 'La suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo'}, {'texto': 'La repetición del sonido producida por la reflexión del sonido en un objeto'}, {'texto': 'El cambio de velocidad y dirección de una onda al pasar de un medio a otro con distinta densidad'}, {'texto': 'La cantidad de energía que se disipa cuando una onda contacta con un material'}], 'ayuda': 'La reverberación es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': '¿Qué ocurre en el fenómeno de refracción del sonido?', 'respuestas': [{'texto': 'La onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad ...
#
#
# TEMA 1. ESTUDIO FÍSICO DEL SONIDO
# {'preguntas': [{'texto': '¿Qué tipo de ondas son las ondas sonoras?', 'respuestas': [{'texto': 'Ondas mecánicas de presión'}, {'texto': 'Ondas electromagnéticas'}, {'texto': 'Ondas gravitacionales'}, {'texto': 'Ondas luminosas'}], 'ayuda': 'Las ondas sonoras son ondas mecánicas de presión que se propagan en un medio elástico y denso.'}, {'texto': '¿Qué unidad de medida se utiliza para la frecuencia del sonido?', 'respuestas': [{'texto': 'Hercios (Hz)'}, {'texto': 'Decibelios (dB)'}, {'texto': 'Amplitud'}, {'texto': 'Presión acústica (PA)'}], 'ayuda': 'La frecuencia del sonido se mide en hercios (Hz).'}, {'texto': '¿En qué rango de frecuencia se encuentra el oído humano de manera óptima?', 'respuestas': [{'texto': 'Entre 1000 y 3000 Hz'}, {'texto': 'Entre 20 y 20.000 Hz'}, {'texto': 'Más de 20.000 Hz'}, {'texto': 'Menos de 1000 Hz'}], 'ayuda': 'El oído humano tiene un rango óptimo de frecuencia entre 1000 y 3000 Hz.'}, {'texto': '¿Qué cualidad del sonido se relaciona con la amplitud?', 'respuestas': [{'texto': 'Intensidad'}, {'texto': 'Frecuencia'}, {'texto': 'Timbre'}, {'texto': 'Duración'}], 'ayuda': 'La amplitud del sonido se relaciona con la intensidad, siendo mayor la amplitud cuanto mayor sea la intensidad del sonido.'}, {'texto': '¿Qué es el nivel de presión sonora (SPL)?', 'respuestas': [{'texto': 'La intensidad percibida'}, {'texto': 'La cantidad de frecuencias'}, {'texto': 'La duración del sonido'}, {'texto': 'La frecuencia fundamental'}], 'ayuda': 'El nivel de presión sonora (SPL) es la intensidad percibida del sonido.'}, {'texto': '¿Qué tipo de onda es un tono simple?', 'respuestas': [{'texto': 'Una única onda sinusoidal'}, {'texto': 'Una onda compleja'}, {'texto': 'Una onda periódica'}, {'texto': 'Una onda cuadrada'}], 'ayuda': 'Un tono simple es una única onda sinusoidal.'}, {'texto': '¿Qué es el timbre de un sonido?', 'respuestas': [{'texto': 'El conjunto de frecuencias que caracterizan a un sonido complejo'}, {'texto': 'La duración del sonido'}, {'texto': 'La intensidad percibida'}, {'texto': 'La frecuencia fundamental'}], 'ayuda': 'El timbre es el conjunto de frecuencias / sobretonos que caracterizan a un sonido complejo.'}, {'texto': '¿Qué es la reverberación?', 'respuestas': [{'texto': 'La suma total de las reflexiones del sonido en diferentes momentos'}, {'texto': 'La reflexión del sonido en un objeto'}, {'texto': 'La refracción del sonido'}, {'texto': 'El efecto Doppler'}], 'ayuda': 'La reverberación es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': '¿En qué medio se propaga más rápido el sonido?', 'respuestas': [{'texto': 'En sólido'}, {'texto': 'En líquido'}, {'texto': 'En gas'}, {'texto': 'En el vacío'}], 'ayuda': 'El sonido se propaga más rápido en sólido que en líquido, y más lento en gas.'}, {'texto': '¿Qué es el eco?', 'respuestas': [{'texto': 'La repetición del sonido por la reflexión en un objeto'}, {'texto': 'La suma total de las reflexiones del sonido'}, {'texto': 'La propagación del sonido en un medio denso'}, {'texto': 'La reverberación del sonido en el aire'}], 'ayuda': 'El eco es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': '¿Qué ocurre con la velocidad de propagación del sonido en un medio más denso?', 'respuestas': [{'texto': 'Aumenta'}, {'texto': 'Disminuye'}, {'texto': 'Permanece igual'}, {'texto': 'Depende de la temperatura'}], 'ayuda': 'En un medio más denso, la velocidad de propagación del sonido aumenta.'}, {'texto': '¿Qué tipo de onda es un tono complejo?', 'respuestas': [{'texto': 'Una unión de varias ondas sinusoidales'}, {'texto': 'Una onda periódica'}, {'texto': 'Una onda cuadrada'}, {'texto': 'Una única onda sinusoidal'}], 'ayuda': 'Un tono complejo es la unión de varias ondas sinusoidales que se perciben como un único sonido.'}, {'texto': '¿Qué es la refracción del sonido?', 'respuestas': [{'texto': 'El cambio de velocidad y dirección al pasar de un medio a o ...
#
#
# 1. FUENTE SONORA VIBRANTE
# {'preguntas': [{'texto': '¿Qué es una fuente sonora vibrante?', 'respuestas': [{'texto': 'Es aquella que genera el sonido'}, {'texto': 'Es el medio por el cual se propaga el sonido'}, {'texto': 'Es el receptor del sonido'}, {'texto': 'Es un obstáculo que refleja el sonido'}], 'ayuda': 'Una fuente sonora vibrante es la que produce el sonido en un sistema auditivo.'}, {'texto': '¿Por qué tipo de medio se propagan las ondas sonoras?', 'respuestas': [{'texto': 'Medio elástico y denso'}, {'texto': 'Medio sólido'}, {'texto': 'Medio gaseoso'}, {'texto': 'Medio líquido'}], 'ayuda': 'Las ondas sonoras se propagan en un medio elástico y denso, como el aire o el agua.'}, {'texto': '¿Cuál es la unidad de medida de la frecuencia?', 'respuestas': [{'texto': 'Hercios (Hz)'}, {'texto': 'Julios'}, {'texto': 'Decibelios (dB)'}, {'texto': 'Pascales'}], 'ayuda': 'La cantidad de vibraciones por segundo de una partícula se mide en hercios (Hz).'}, {'texto': '¿Qué diferencia hay entre sonido grave y sonido agudo?', 'respuestas': [{'texto': 'Frecuencia baja es grave, frecuencia alta es agudo'}, {'texto': 'Amplitud baja es grave, amplitud alta es agudo'}, {'texto': 'Frecuencia alta es grave, frecuencia baja es agudo'}, {'texto': 'Amplitud alta es grave, amplitud baja es agudo'}], 'ayuda': 'Un sonido grave tiene una frecuencia baja, mientras que un sonido agudo tiene una frecuencia alta.'}, {'texto': '¿Qué representa la amplitud de una onda sonora?', 'respuestas': [{'texto': 'El grado de movimiento de las moléculas de aire'}, {'texto': 'La dirección de propagación'}, {'texto': 'La velocidad del sonido'}, {'texto': 'La frecuencia del sonido'}], 'ayuda': 'La amplitud representa el grado de movimiento de las moléculas de aire en una onda sonora.'}, {'texto': '¿Qué es el nivel de presión sonora (SPL)?', 'respuestas': [{'texto': 'La intensidad percibida del sonido'}, {'texto': 'La distancia de propagación del sonido'}, {'texto': 'La frecuencia del sonido'}, {'texto': 'La dirección de desplazamiento'}], 'ayuda': 'El nivel de presión sonora (SPL) es la intensidad percibida del sonido por el aparato auditivo.'}, {'texto': '¿Cómo se define un sonido cálido en términos de armónicos?', 'respuestas': [{'texto': 'Con un número elevado de armónicos'}, {'texto': 'Con armónicos muy agudos'}, {'texto': 'Con una única frecuencia fundamental'}, {'texto': 'Con armónicos en baja amplitud'}], 'ayuda': 'Un sonido cálido se caracteriza por tener un número elevado de armónicos en su composición.'}, {'texto': '¿Qué es el timbre de un sonido?', 'respuestas': [{'texto': 'El conjunto de frecuencias que caracterizan a un sonido'}, {'texto': 'La duración del sonido'}, {'texto': 'La amplitud del sonido'}, {'texto': 'La intensidad percibida del sonido'}], 'ayuda': 'El timbre de un sonido es el conjunto de frecuencias / sobretonos que lo caracterizan.'}, {'texto': '¿Qué es la reverberación en la propagación del sonido?', 'respuestas': [{'texto': 'La suma de las reflexiones que llegan al oyente'}, {'texto': 'La pérdida de energía en el sonido'}, {'texto': 'El cambio de dirección del sonido al pasar de un medio a otro'}, {'texto': 'La variación de frecuencia al acercarse la fuente'}], 'ayuda': 'La reverberación es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': '¿Qué factores afectan a la propagación del sonido?', 'respuestas': [{'texto': 'Reflexión, eco, refracción, absorbción'}, {'texto': 'Frecuencia, duración, amplitud, dirección'}, {'texto': 'Timbre, resonancia, efecto Doppler, impedancia'}, {'texto': 'Elasticidad, inercia, densidad, masa'}], 'ayuda': 'Factores como reflexión, eco, refracción y absorción influyen en la propagación del sonido en un medio.'}, {'texto': '¿Qué fenómeno produce el cambio de frecuencia de una onda sonora por el movimiento de la fuente?', 'respuestas': [{'texto': 'Efecto Doppler'}, {'texto': 'Reverberación'}, {'texto': 'Absorción'}, {'texto': 'Resonancia'}], 'ayuda': 'El aparente cam ...
#
#
# 1.1. Cualidades esenciales de las ondas sonoras
# {'preguntas': [{'texto': '¿Qué tipo de desplazamientos presentan las ondas sonoras?', 'respuestas': [{'texto': 'Desplazamientos longitudinales y tridimensionales'}, {'texto': 'Desplazamientos horizontales y verticales'}, {'texto': 'Desplazamientos circulares y diagonales'}, {'texto': 'Desplazamientos estáticos y dinámicos'}], 'ayuda': 'Las ondas sonoras presentan desplazamientos longitudinales, donde la dirección de desplazamiento es igual a la del medio, y desplazamientos tridimensionales.'}, {'texto': '¿Qué cualidad de las ondas sonoras se mide en hercios?', 'respuestas': [{'texto': 'Frecuencia / Tono'}, {'texto': 'Amplitud / Intensidad'}, {'texto': 'Timbre'}, {'texto': 'Duración'}], 'ayuda': 'La frecuencia o tono de las ondas sonoras se mide en hercios (Hz).'}, {'texto': '¿Qué rango de frecuencia es óptimo para el oído humano?', 'respuestas': [{'texto': 'Entre los 1000 - 3000 Hz'}, {'texto': 'Entre los 20 - 20.000 Hz'}, {'texto': 'Superior a los 3000 Hz'}, {'texto': 'Inferior a los 1000 Hz'}], 'ayuda': 'El oído humano tiene un rango óptimo de percepción entre los 1000 - 3000 Hz, aunque es capaz de percibir frecuencias entre los 20 - 20.000 Hz.'}, {'texto': '¿Qué significa la amplitud en las ondas sonoras?', 'respuestas': [{'texto': 'Es el grado de movimiento de las moléculas de aire que componen una onda'}, {'texto': 'Es la cantidad de vibraciones por segundo de una partícula'}, {'texto': 'Es el conjunto de frecuencias que caracterizan a un sonido complejo'}, {'texto': 'Es la velocidad de propagación del sonido'}], 'ayuda': 'La amplitud en las ondas sonoras representa el grado de movimiento de las moléculas de aire que forman la onda.'}, {'texto': '¿Qué unidad de medida se utiliza para la amplitud de una onda sonora?', 'respuestas': [{'texto': 'Decibelios (dB)'}, {'texto': 'Hercios (Hz)'}, {'texto': 'Pascales (Pa)'}, {'texto': 'Vatios (W)'}], 'ayuda': 'La amplitud de una onda sonora se mide en decibelios (dB).'}, {'texto': '¿Cuál es la diferencia principal entre tonos simples y tonos complejos?', 'respuestas': [{'texto': 'Tonos simples son una única onda sinusoidal, mientras que tonos complejos son la unión de varias ondas sinusoidales'}, {'texto': 'Tonos simples son más agudos que los tonos complejos'}, {'texto': 'Tonos complejos tienen mayor duración que los tonos simples'}, {'texto': 'Tonos complejos presentan una frecuencia fundamental constante'}], 'ayuda': 'Los tonos simples son una única onda sinusoidal, es decir, una sola frecuencia; mientras que los tonos complejos son la unión de varias ondas sinusoidales.'}, {'texto': '¿Qué es el timbre de un sonido?', 'respuestas': [{'texto': 'El conjunto de frecuencias / sobretonos que caracterizan a un sonido complejo'}, {'texto': 'La duración total de un sonido'}, {'texto': 'La intensidad recibida de un sonido'}, {'texto': 'La velocidad de propagación sonora'}], 'ayuda': 'El timbre de un sonido es el conjunto de frecuencias y sobretonos que caracterizan a un sonido complejo, permitiendo diferenciarlo de otros sonidos.'}, {'texto': '¿Qué es la duración en el contexto de las ondas sonoras?', 'respuestas': [{'texto': 'Cuanto mayor es la duración, mayor velocidad tiene el sonido'}, {'texto': 'La diferencia entre la frecuencia fundamental y los armónicos'}, {'texto': 'La distancia máxima a la que se propaga un eco'}, {'texto': 'El tiempo que transcurre desde una reflexión hasta la siguiente'}], 'ayuda': 'En el contexto de las ondas sonoras, la duración se refiere a que cuanto mayor es ésta, mayor velocidad tiene el sonido.'}, {'texto': '¿Qué propiedades debe tener un medio para poder propagar el sonido?', 'respuestas': [{'texto': 'Masa, inercia y elasticidad'}, {'texto': 'Densidad, temperatura y humedad'}, {'texto': 'Resonancia, absorción y refracción'}, {'texto': 'Presión, amplitud y velocidad'}], 'ayuda': 'Un medio para propagar el sonido debe tener masa (peso), inercia y elasticidad como propiedades fundamentales.'}, {'texto': '¿En qué medio se propaga más rápido el sonido?', ' ...
#
#
# 2. MEDIO DE PROPAGACIÓN
# {'preguntas': [{'texto': '¿Qué tipo de ondas son las ondas sonoras?', 'respuestas': [{'texto': 'Ondas mecánicas de presión'}, {'texto': 'Ondas electromagnéticas'}, {'texto': 'Ondas de luz'}, {'texto': 'Ondas gravitacionales'}], 'ayuda': 'Las ondas sonoras son ondas mecánicas de presión que se propagan en un medio elástico y denso, como el aire, el agua o el metal.'}, {'texto': '¿Qué es la frecuencia en relación al sonido?', 'respuestas': [{'texto': 'La cantidad de vibraciones por segundo de una partícula'}, {'texto': 'La intensidad del sonido'}, {'texto': 'La amplitud del sonido'}, {'texto': 'La duración del sonido'}], 'ayuda': 'La frecuencia de una onda sonora es la cantidad de vibraciones por segundo de una partícula y se mide en hercios (Hz).'}, {'texto': '¿En qué rango de frecuencia se encuentra el oído humano de forma óptima?', 'respuestas': [{'texto': 'Entre los 1000 - 3000 Hz'}, {'texto': 'Entre los 20 - 20.000 Hz'}, {'texto': 'Menos de 100 Hz'}, {'texto': 'Más de 5000 Hz'}], 'ayuda': 'El oído humano tiene un rango óptimo de percepción entre los 1000 - 3000 Hz, a pesar de que puede percibir sonidos entre los 20 - 20.000 Hz.'}, {'texto': '¿Qué es la amplitud en relación al sonido?', 'respuestas': [{'texto': 'El grado de movimiento de las moléculas de aire que componen una onda'}, {'texto': 'La frecuencia del sonido'}, {'texto': 'La duración del sonido'}, {'texto': 'La velocidad del sonido'}], 'ayuda': 'La amplitud en relación al sonido se refiere al grado de movimiento de las moléculas de aire que componen una onda sonora.'}, {'texto': '¿En qué unidades se mide la amplitud de una onda sonora?', 'respuestas': [{'texto': 'Decibelios (dB)'}, {'texto': 'Hercios (Hz)'}, {'texto': 'Vatios (W)'}, {'texto': 'Julios (J)'}], 'ayuda': 'La amplitud de una onda sonora se mide en decibelios (dB) para expresar la intensidad recibida.'}, {'texto': '¿Qué diferencia hay entre la presión acústica y el nivel de presión sonora?', 'respuestas': [{'texto': 'La presión acústica se mide en pascales y el nivel de presión sonora en decibelios'}, {'texto': 'La presión acústica es más alta que el nivel de presión sonora'}, {'texto': 'La presión acústica depende de la distancia y el nivel de presión sonora no'}, {'texto': 'La presión acústica se mide en hercios y el nivel de presión sonora en octavas'}], 'ayuda': 'La presión acústica se mide en pascales, pero en la práctica se utilizan los decibelios; mientras que el nivel de presión sonora es la intensidad percibida.'}, {'texto': '¿Qué son los tonos simples en relación al sonido?', 'respuestas': [{'texto': 'Son una única onda sinusoidal'}, {'texto': 'Son la unión de varias ondas sinusoidales'}, {'texto': 'Son períodos de silencio en el sonido'}, {'texto': 'Son frecuencias muy altas'}], 'ayuda': 'Los tonos simples en sonido son una única onda sinusoidal, es decir, una sola frecuencia.'}, {'texto': '¿Qué es el timbre en relación al sonido?', 'respuestas': [{'texto': 'El conjunto de frecuencias/sobretonos que caracterizan a un sonido complejo'}, {'texto': 'La frecuencia más grave de un sonido'}, {'texto': 'La duración total de un sonido'}, {'texto': 'La amplitud máxima de un sonido'}], 'ayuda': 'El timbre en relación al sonido se refiere al conjunto de frecuencias/sobretonos que caracterizan a un sonido complejo.'}, {'texto': '¿Cuál es la principal diferencia entre eco y reverberación?', 'respuestas': [{'texto': 'La distancia en la que llegan las reflexiones al oyente'}, {'texto': 'El número de ondas reflejadas'}, {'texto': 'El tiempo que tardan en llegar las reflexiones al oyente'}, {'texto': 'El material del que está hecho el objeto reflejante'}], 'ayuda': 'La principal diferencia entre eco y reverberación es la distancia a la que llegan las reflexiones al oyente: eco requiere una mayor distancia.'}, {'texto': '¿Qué fenómeno se produce cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad?', 'respuestas': [{'texto': 'Refracción'}, {'texto': 'Reflexión'}, {' ...
#
#
# a) REFLEXIÓN, ECO Y REVERBERACIÓN
# {'preguntas': [{'texto': '¿Qué es la reflexión en relación al sonido?', 'respuestas': [{'texto': 'Es el fenómeno que ocurre cuando una onda sonora choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': 'Es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': 'Es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad.'}], 'ayuda': 'La reflexión es el fenómeno que ocurre cuando una onda sonora choca contra un obstáculo que no puede traspasar ni rodear, como se menciona en el texto proporcionado.'}, {'texto': '¿Qué es el eco en relación al sonido?', 'respuestas': [{'texto': 'Es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda sonora choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': 'Es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad.'}], 'ayuda': 'El eco es la repetición del sonido producida por la reflexión del sonido en un objeto, según lo expuesto en el temario.'}, {'texto': '¿Qué es la reverberación en relación al sonido?', 'respuestas': [{'texto': 'Es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda sonora choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': 'Es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad.'}], 'ayuda': 'La reverberación es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo, como se describe en el texto del temario.'}, {'texto': '¿Cómo se define el eco según el temario?', 'respuestas': [{'texto': 'Es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': 'Es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda sonora choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': 'Es el fenómeno que ocurre cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad.'}], 'ayuda': 'El eco es la repetición del sonido producida por la reflexión del sonido en un objeto, tal como se explica en el texto proporcionado.'}, {'texto': '¿Qué diferencia la reverberación del eco en relación al sonido?', 'respuestas': [{'texto': 'La distancia.'}, {'texto': 'El tiempo de recepción con ida y vuelta.'}, {'texto': 'La cantidad de energía disipada.'}, {'texto': 'El cambio de velocidad y dirección.'}], 'ayuda': 'La principal diferencia entre la reverberación y el eco es la distancia, como se menciona en el temario.'}, {'texto': '¿Cuál es la aplicación mencionada del eco en el temario?', 'respuestas': [{'texto': 'Ecografía'}, {'texto': 'Absorción'}, {'texto': 'Refracción'}, {'texto': 'Resonancia'}], 'ayuda': 'Entre las aplicaciones mencionadas del eco se encuentran la Ecografía, como se indica en el temario.'}, {'texto': '¿Qué factores influyen en la propagación del sonido según el temario?', 'respuestas': [{'texto': 'Masa, inercia y elasticidad.'}, {'texto': 'Presión acústica y nivel de presión sonora.'}, {'texto': 'Tiempo y duración.'}, {'texto': 'Densidad del medio y velocidad.'}, {'texto': 'Reflección, eco y refracción.'}], 'ayuda': 'Los factores que afectan a la propagación del sonido incluyen la masa, la inercia, la elasticidad, l ...
#
#
# b) REFRACCIÓN
# {'preguntas': [{'texto': '¿Qué es la refracción?', 'respuestas': [{'texto': 'Es el fenómeno que ocurre cuando una onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad.'}, {'texto': 'Es la cantidad de energía que se disipa cuando una onda contacta con un determinado material.'}, {'texto': 'Es la repetición del sonido producida por la reflexión del sonido en un objeto.'}, {'texto': 'Es el aparente cambio de frecuencia de una onda sonora producida por el movimiento de la fuente con respecto al observador.'}], 'ayuda': 'La refracción es un fenómeno que involucra cambios en la velocidad y dirección de una onda al pasar de un medio a otro con distinta densidad. Es diferente de la reflexión, absorción y efecto Doppler.'}, {'texto': '¿Qué ley se cumple en la refracción?', 'respuestas': [{'texto': 'Ley de Snell'}, {'texto': 'Ley de Einstein'}, {'texto': 'Ley de Newton'}, {'texto': 'Ley de Ohm'}], 'ayuda': 'En la refracción, la dirección y velocidad de una onda cambian al pasar de un medio a otro. Esto se rige por la Ley de Snell, mientras que la Ley de Einstein, de Newton y de Ohm se aplican a otros fenómenos.'}, {'texto': '¿Qué ocurre con el ángulo del rayo incidente y el ángulo del rayo refractado en la refracción?', 'respuestas': [{'texto': 'Son distintos'}, {'texto': 'Son iguales'}, {'texto': 'Se anulan'}, {'texto': 'No tienen relación'}], 'ayuda': 'En el fenómeno de la refracción, el ángulo del rayo incidente y el ángulo del rayo refractado son diferentes. Esto contrasta con la reflexión donde ambos ángulos son iguales.'}, {'texto': '¿Qué sucede con una onda al cambiar de medio en la refracción?', 'respuestas': [{'texto': 'Cambia su velocidad y dirección'}, {'texto': 'No cambia nada'}, {'texto': 'Se anula'}, {'texto': 'Aumenta su amplitud'}], 'ayuda': 'En la refracción, una onda experimenta cambios en su velocidad y dirección al pasar de un medio a otro con distinta densidad. Esto es clave para entender cómo se comporta el sonido al cambiar de entorno.'}, {'texto': '¿En qué se diferencia la refracción de la reflexión?', 'respuestas': [{'texto': 'En la dirección y cambio de velocidad de la onda'}, {'texto': 'En la repetición del sonido'}, {'texto': 'En la variabilidad de la intensidad percibida'}, {'texto': 'En el cambio aparente de frecuencia de la onda sonora.'}], 'ayuda': 'La refracción implica cambios en la dirección y velocidad de una onda al cambiar de medio, mientras que la reflexión se refiere al rebote de la onda contra un obstáculo.'}, {'texto': '¿Cuál es el fenómeno opuesto a la refracción?', 'respuestas': [{'texto': 'Reflexión'}, {'texto': 'Eco'}, {'texto': 'Reverberación'}, {'texto': 'Absorción'}], 'ayuda': 'La refracción implica cambios en la dirección y velocidad de una onda al pasar de un medio a otro. Por otro lado, la reflexión es el rebote de la onda contra un objeto sin cambiar de medio.'}, {'texto': '¿Cuál es la función principal de la ley de Snell?', 'respuestas': [{'texto': 'Relacionar los ángulos del rayo incidente y reflejado en la refracción'}, {'texto': 'Calcular la amplitud de una onda sonora'}, {'texto': 'Determinar la intensidad percibida de un sonido'}, {'texto': 'Medir la duración de una onda sonora'}], 'ayuda': 'La ley de Snell se utiliza para relacionar los ángulos del rayo incidente y del rayo reflejado en el fenómeno de la refracción. Es crucial para comprender cómo cambia la dirección de una onda al pasar de un medio a otro.'}, {'texto': '¿Cuál es la diferencia principal entre eco y refracción?', 'respuestas': [{'texto': 'La formación de sonidos repetidos versus el cambio en dirección y velocidad de la onda'}, {'texto': 'El retardo en la recepción del sonido versus la repetición del sonido'}, {'texto': 'La variabilidad de la intensidad percibida versus la suma total de reflexiones del sonido'}, {'texto': 'La densidad del medio versus la velocidad de propagación del sonido'}], 'ayuda': 'El eco implica la repetición de sonidos debido a la reflexión, mientras que l ...
#
#
# Absorción
# {'preguntas': [{'texto': '¿Qué es la absorción en el contexto del sonido?', 'respuestas': [{'texto': 'Es la cantidad de energía que se disipa cuando una onda contacta con un determinado material.'}, {'texto': 'Es el cambio de velocidad y dirección al pasar de un medio a otro con distinta densidad.'}, {'texto': 'Es la vibración de un objeto que hace que vibre otro objeto sin contacto.'}, {'texto': 'Es el aparente cambio de frecuencia de una onda sonora por el movimiento de la fuente con respecto al observador.'}], 'ayuda': 'La absorción es la cantidad de energía que se disipa cuando una onda contacta con un determinado material, según el texto del temario.'}, {'texto': '¿Qué tipos de materiales absorbentes existen?', 'respuestas': [{'texto': 'Materiales resonantes, materiales porosos, absorbentes en forma de panel.'}, {'texto': 'Materiales reflectantes, materiales duros, absorbentes en forma de líquido.'}, {'texto': 'Materiales aislantes, materiales conductores, absorbentes en forma de gas.'}, {'texto': 'Materiales duros, materiales rígidos, absorbentes en forma de sólido.'}], 'ayuda': 'Según el temario, los tipos de materiales absorbentes son materiales resonantes, materiales porosos y absorbentes en forma de panel.'}, {'texto': '¿Qué característica de los materiales resonantes permite su máxima absorción a una determinada frecuencia?', 'respuestas': [{'texto': 'Tienen puntos de máxima absorción a una determinada frecuencia.'}, {'texto': 'Absorben más sonido conforme va aumentando la frecuencia.'}, {'texto': 'Absorben frecuencias bajas.'}, {'texto': 'Transforman la energía acústica en calor.'}], 'ayuda': 'Según el temario, los materiales resonantes tienen puntos de máxima absorción a una determinada frecuencia.'}, {'texto': '¿Cómo se clasifican los materiales absorbentes por su estructura?', 'respuestas': [{'texto': 'Materiales resonantes, materiales porosos, absorbentes en forma de panel.'}, {'texto': 'Materiales reflectantes, materiales duros, absorbentes en forma de líquido.'}, {'texto': 'Materiales aislantes, materiales metálicos, absorbentes en forma de gas.'}, {'texto': 'Materiales blandos, materiales duros, absorbentes en forma de sólido.'}], 'ayuda': 'Según el temario, se clasifican en materiales resonantes, materiales porosos y absorbentes en forma de panel.'}, {'texto': '¿Qué tipo de materiales absorben más sonido conforme va aumentando la frecuencia?', 'respuestas': [{'texto': 'Materiales porosos.'}, {'texto': 'Materiales resonantes.'}, {'texto': 'Absorbentes en forma de panel.'}, {'texto': 'Materiales duros.'}], 'ayuda': 'Los materiales porosos, según el temario, absorben más sonido conforme va aumentando la frecuencia.'}, {'texto': '¿Qué tipos de factores afectan a la absorción del sonido en un determinado material?', 'respuestas': [{'texto': 'Frecuencia, temperatura, humedad.'}, {'texto': 'Densidad, grosor, forma.'}, {'texto': 'Color, textura, luminosidad.'}, {'texto': 'Presión, altura, longitud.'}], 'ayuda': 'Según el temario, los factores que afectan a la absorción del sonido son la frecuencia, la temperatura y la humedad.'}, {'texto': '¿Qué efecto produce la absorción del aire en el sonido?', 'respuestas': [{'texto': 'Transforma parte de la energía acústica en calor.'}, {'texto': 'Disminuye la velocidad del sonido.'}, {'texto': 'Aumenta la intensidad del sonido.'}, {'texto': 'Modifica la frecuencia del sonido.'}], 'ayuda': 'La absorción del aire, según el temario, transforma parte de la energía acústica en calor.'}, {'texto': '¿Qué se utiliza para medir la intensidad recibida de la presión acústica?', 'respuestas': [{'texto': 'Decibelios (dB).'}, {'texto': 'Hercios (Hz).'}, {'texto': 'Pascales (Pa).'}, {'texto': 'Julios (J).'}], 'ayuda': 'La intensidad recibida de la presión acústica se mide en decibelios (dB), de acuerdo al temario.'}, {'texto': '¿Qué es el nivel de presión sonora?', 'respuestas': [{'texto': 'La intensidad percibida del sonido.'}, {'texto': 'La cantidad de vibraciones por segundo de una partí ...
#
#
# Resonancia
# {'preguntas': [{'texto': '¿Qué es la resonancia?', 'respuestas': [{'texto': 'La resonancia se produce cuando la vibración de un objeto hace que vibre otro objeto sin contacto.'}, {'texto': 'La resonancia es la cantidad de energía que se disipa cuando una onda contacta con un material.'}, {'texto': 'La resonancia es el cambio de frecuencia de una onda debido al movimiento de la fuente.'}, {'texto': 'La resonancia es el fenómeno que ocurre cuando una onda cambia su velocidad al pasar de un medio a otro.'}], 'ayuda': 'La resonancia se define en el texto como la vibración de un objeto que hace vibrar otro objeto sin contacto.'}, {'texto': '¿Qué factores afectan la propagación del sonido?', 'respuestas': [{'texto': 'Reflexión, eco, reverberación, refracción y absorción.'}, {'texto': 'La masa, la inercia y la elasticidad del medio.'}, {'texto': 'La frecuencia y la temperatura del material absorbente.'}, {'texto': 'La velocidad y la dirección del sonido en el aire.'}], 'ayuda': 'El texto menciona factores como reflexión, eco, reverberación, refracción y absorción que afectan a la propagación del sonido.'}, {'texto': '¿Qué es el Efecto Doppler?', 'respuestas': [{'texto': 'Es el cambio aparente de frecuencia de una onda debido al movimiento de la fuente o el observador.'}, {'texto': 'Es la vibración de objetos que se transmiten energía sin contacto.'}, {'texto': 'Es la reflexión del sonido en un objeto que produce la repetición del sonido.'}, {'texto': 'Es la cantidad de vibraciones por segundo de una partícula.'}, 'ayuda']}, {'texto': '¿Qué es la frecuencia fundamental de un sonido?', 'respuestas': [{'texto': 'Es la frecuencia más grave que origina los sobretonos.'}, {'texto': 'Es la frecuencia percibida por el ser humano.'}, {'texto': 'Es la frecuencia que determina la amplitud del sonido.'}, {'texto': 'Es la frecuencia de las ondas sonoras al pasar por el sistema auditivo.'}, 'ayuda']}, {'texto': '¿Qué es el timbre de un sonido?', 'respuestas': [{'texto': 'Es el conjunto de frecuencias / sobretonos que caracterizan a un sonido complejo.'}, {'texto': 'Es la cantidad de vibraciones por segundo de una partícula.'}, {'texto': 'Es la intensidad de la onda sonora.'}, {'texto': 'Es la duración del sonido.'}, 'ayuda']}, {'texto': '¿Qué son los tonos simples y complejos en el sonido?', 'respuestas': [{'texto': 'Los tonos simples son una sola frecuencia, los complejos son varias frecuencias.'}, {'texto': 'Los tonos complejos son solo una frecuencia, los simples son varias frecuencias.'}, {'texto': 'Los tonos simples no existen en la naturaleza, los complejos son comunes.'}, {'texto': 'Los tonos complejos son más habituales en la naturaleza.'}, 'ayuda']}, {'texto': '¿Qué es la absorción en relación al sonido?', 'respuestas': [{'texto': 'Es la cantidad de energía que se disipa cuando una onda impacta en un material.'}, {'texto': 'Es la capacidad de recuperar la posición inicial tras el movimiento.'}, {'texto': 'Es una propiedad de los materiales porosos.'}, {'texto': 'Es la energía que se transforma en calor al producirse ondas sonoras.'}, 'ayuda']}, {'texto': '¿Qué es la modificación de la sensación acústica en un sonido?', 'respuestas': [{'texto': 'Depende de la intensidad o tipo de armónicos presentes en el sonido.'}, {'texto': 'Depende de la frecuencia fundamental del sonido.'}, {'texto': 'Depende de la duración del sonido.'}, {'texto': 'Depende de la velocidad a la que se propaga el sonido.'}, 'ayuda']}, {'texto': '¿Cuál es la diferencia entre eco y reverberación?', 'respuestas': [{'texto': 'La diferencia es la distancia que recorre el sonido en cada fenómeno.'}, {'texto': 'La diferencia es la cantidad de armónicos presentes en cada fenómeno.'}, {'texto': 'La diferencia es la dirección de las ondas sonoras en cada fenómeno.'}, {'texto': 'No hay diferencia entre eco y reverberación.'}, 'ayuda']}, {'texto': '¿Cómo se mide la amplitud en una onda sonora?', 'respuestas': [{'texto': 'Dibujando una línea horizontal en el centro de la onda y midi ...
#
#
# Efecto Doppler
# Error en el JSON del apartado Efecto Doppler: Expecting ':' delimiter: line 5088 column 1 (char 25307)
# Se generaron 186 preguntas en total.
# [{'texto': '¿Qué son las ondas sonoras?', 'respuestas': [{'texto': 'Ondas mecánicas de presión que se propagan en un medio elástico y denso'}, {'texto': 'Ondas electromagnéticas que se propagan en el aire'}, {'texto': 'Ondas de luz que se mueven en el agua'}, {'texto': 'Ondas eléctricas que se transmiten por el metal'}], 'ayuda': 'Las ondas sonoras son aquellas que, tras pasar por nuestro sistema auditivo, se convierten en información que el cerebro descodifica. Son ondas mecánicas de presión que se propagan en un medio elástico y denso.'}, {'texto': '¿Cuál es la unidad de medida de la frecuencia?', 'respuestas': [{'texto': 'Hercios (Hz)'}, {'texto': 'Decibelios (dB)'}, {'texto': 'Pascales (Pa)'}, {'texto': 'Vatios (W)'}], 'ayuda': 'La frecuencia se mide en hercios (Hz).'}, {'texto': '¿Qué cualidad del sonido está relacionada con la amplitud?', 'respuestas': [{'texto': 'Intensidad'}, {'texto': 'Timbre'}, {'texto': 'Frecuencia'}, {'texto': 'Duración'}], 'ayuda': 'La amplitud del sonido está relacionada con la intensidad, que es el grado de movimiento de las moléculas de aire que componen una onda.'}, {'texto': "¿A qué se refiere el concepto de 'nivel de presión sonora (SPL)'?", 'respuestas': [{'texto': 'Intensidad percibida del sonido'}, {'texto': 'Intensidad emitida del sonido'}, {'texto': 'Intensidad por decibelios'}, {'texto': 'Intensidad por pascales'}], 'ayuda': 'El nivel de presión sonora (SPL) se refiere a la intensidad percibida del sonido.'}, {'texto': '¿Qué son los tonos simples en relación a las ondas sonoras?', 'respuestas': [{'texto': 'Una única onda sinusoidal con una sola frecuencia'}, {'texto': 'La superposición de múltiples ondas sinusoidales'}, {'texto': 'Ondas de luz monocromáticas'}, {'texto': 'Ruidos ondulatorios irregulares'}], 'ayuda': 'Los tonos simples son una única onda sinusoidal, es decir, una sola frecuencia.'}, {'texto': '¿Qué es el timbre en relación al sonido?', 'respuestas': [{'texto': 'Conjunto de frecuencias/sobretonos que caracterizan un sonido complejo'}, {'texto': 'La duración total de un sonido'}, {'texto': 'La amplitud máxima alcanzada por una onda sonora'}, {'texto': 'La frecuencia más grave de un sonido'}], 'ayuda': 'El timbre es el conjunto de frecuencias o sobretonos que caracterizan a un sonido complejo.'}, {'texto': '¿Qué afecta a la velocidad de propagación del sonido en un medio?', 'respuestas': [{'texto': 'Densidad del medio'}, {'texto': 'Color del medio'}, {'texto': 'Peso del medio'}, {'texto': 'Forma del medio'}], 'ayuda': 'La velocidad de propagación del sonido en un medio es afectada por la densidad del medio. Cuanto más denso el medio, más rápido se propaga el sonido.'}, {'texto': '¿Qué fenómeno es la reflexión del sonido?', 'respuestas': [{'texto': 'Cuando una onda choca contra un obstáculo que no puede traspasar ni rodear'}, {'texto': 'Cuando una onda se dobla al pasar de un medio a otro'}, {'texto': 'Cuando una onda se desvanece con el tiempo'}, {'texto': 'Cuando una onda cambia su dirección al atravesar un material'}], 'ayuda': 'La reflexión del sonido es el fenómeno que ocurre cuando una onda choca contra un obstáculo que no puede traspasar ni rodear.'}, {'texto': '¿Qué es la reverberación en relación al sonido?', 'respuestas': [{'texto': 'La suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo'}, {'texto': 'La repetición del sonido producida por la reflexión del sonido en un objeto'}, {'texto': 'El cambio de velocidad y dirección de una onda al pasar de un medio a otro con distinta densidad'}, {'texto': 'La cantidad de energía que se disipa cuando una onda contacta con un material'}], 'ayuda': 'La reverberación es la suma total de las reflexiones del sonido que llegan al lugar del oyente en diferentes momentos del tiempo.'}, {'texto': '¿Qué ocurre en el fenómeno de refracción del sonido?', 'respuestas': [{'texto': 'La onda cambia su velocidad y dirección al pasar de un medio a otro con distinta densidad'}, {'texto':  ...

# %%
from django.core.files.uploadedfile import SimpleUploadedFile

ruta_al_archivo = '/home/monica/Descargas/fisio_pdf/Tema_1_fisio.pdf'
with open(ruta_al_archivo, 'rb') as f:
    contenido_archivo = f.read()

archivo_simulado = SimpleUploadedFile("archivo.txt", contenido_archivo)

temario = extraer_texto_pdf(archivo_simulado)

# %%
print(preguntas_generadas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(preguntas_generadas)
#
# NameError: name 'preguntas_generadas' is not defined

# %%
# Out:
# --------------
# APARTADOS
# {
#     "apartados": [
#         {
#             "titulo": "Tema 1. ESTUDIO FÍSICO DEL SONIDO",
#             "subapartados": [
#                 {"titulo": "1. FUENTE SONORA VIBRANTE"},
#                 {"titulo": "1.1. Cualidades esenciales de las ondas sonoras",
#                     "subapartados": [
#                         {"titulo": "a) FRECUENCIA / TONO"},
#                         {"titulo": "b) AMPLITUD / INTENSIDAD"}
#                     ]
#                 }
#             ]
#         },
#         {
#             "titulo": "2. MEDIO DE PROPAGACIÓN",
#             "subapartados": [
#                 {"titulo": "Factores que afectan a la propagación del sonido",
#                     "subapartados": [
#                         {"titulo": "a) REFLEXIÓN, ECO Y REVERBERACIÓN"},
#                         {"titulo": "b) REFRACCIÓN"},
#                         {"titulo": "Absorción"},
#                         {"titulo": "Resonancia"},
#                         {"titulo": "Efecto Doppler"}
#                     ]
#                 }
#             ]
#         }
#     ]
# }
# --------------
# None
